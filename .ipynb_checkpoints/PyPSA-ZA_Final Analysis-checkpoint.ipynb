# %% [markdown]
# Agatha Justina Majcher
# M.Sc. Renewable Energy Systems

# %% [markdown]
# # Distributional Analysis of the Carbon Tax in South Africa

# %% [markdown]
# Part II - PyPSA-ZA
# Revenue Recycling through Investment in Renewable Energies

# %% [markdown]
# # 1. Setup

# %%
import sys
sys.path.append("~/Desktop/PyPsa")

# %%
import pypsa
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use("bmh")
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# solved_network files
# n = pypsa.Network("results/networks/solved_val-LC-UNC_27-supply_redz_lcopt_LC-2190H.nc")
# n = pypsa.Network("results/networks/solved_val-LC-UNC_27-supply_redz_lcopt_Co2L-2190H.nc")
# n = pypsa.Network("results/networks/solved_val-LC-UNC_27-supply_redz_lcopt_Co2L-25sn.nc")

n = pypsa.Network("results/networks/solved_val-LC-UNC_27-supply_redz_lcopt_Co2L-25sn.nc")
# Out:
# WARNING:pypsa.io:Importing network from PyPSA version v0.22.0 while current version is v0.22.1. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.io:Imported network solved_val-LC-UNC_27-supply_redz_lcopt_Co2L-25sn.nc has buses, carriers, generators, global_constraints, lines, loads, storage_units

# %% [markdown]
# # 2. Network Component Analysis

# %% [markdown]
# #### Network Plot

# %%
n.plot();

# %% [markdown]
# #### Components of Network
#
# Network - Container for all Components
# Bus - Node where components attach
# Carrier - Energy carrier or technology e.g. gas, coal, oil, biomass, on-/offshore wind, solar)
# Load - Energy consumer (e.g. electricity demand)
# Generator - Generator (e.g. power plant, wind turbine, PV panel)
# Line - Power distribution and transmission lines (overhead and cables)
# Link - Links connect two buses with controllable energy flow, direction-control and losses
# StorageUnit - Storage with fixed nominal energy-to-power ratio
# GlobalConstraint - Constraints affecting many components at once, such as emission limits
# Store - Storage with separately extendable energy capacity
# LineType - Standard line types.
# Transformer - 2-winding transformer.
# TransformerType - Standard types of 2-winding transformer.
# ShuntImpedance - Shunt.

# %%
for c in n.iterate_components(list(n.components.keys())[2:]):
    print("Component '{}' has {} entries".format(c.name,len(c.df)))

# %% [markdown]
# #### Temporal Resolution

# %%
n.snapshots[:10]

# %%
len(n.snapshots)

# %% [markdown]
# # 2.1 Loads

# %%
n.loads.head()

# %%
n.loads_t.p_set #.head()

# %%
# Load values

# %%
load_values = n.loads_t.p_set
print(load_values)

# %%
n.loads_t.p_set.sum(axis=1).plot(figsize=(15,3))

# %%
# Regional Distribution of loads

# %%
load = n.loads_t.p_set.sum(axis=0).groupby(n.loads.bus).sum()

# %%
fig = plt.figure()
ax = plt.axes(projection=ccrs.EqualEarth())

n.plot(
    ax=ax,
    bus_sizes=load/2e5,
);

# %% [markdown]
# # 2.2 Generators

# %%
n.generators.head()
# Out:
#                       bus carrier  build_year  lifetime   p_nom  \
# Generator
# Arnot*     HIGHVELD NORTH    coal        2020       6.0  1116.0
# Arnot**    HIGHVELD NORTH    coal        2020      10.0  1116.0
# Camden*    HIGHVELD SOUTH    coal        2020       1.0   740.0
# Camden**   HIGHVELD SOUTH    coal        2020       4.0   370.0
# Duvha*     HIGHVELD NORTH    coal        2020      11.0  1150.0
#
#            p_nom_extendable  efficiency  ramp_limit_up  ramp_limit_down  \
# Generator
# Arnot*                False    0.282486       0.112903         0.112903
# Arnot**               False    0.282486       0.112903         0.112903
# Camden*               False    0.265018       0.089189         0.089189
# Camden**              False    0.252101       0.178378         0.178378
# Duvha*                False    0.298359       0.172174         0.172174
#
#            marginal_cost  ...  sign committable start_up_cost  shut_down_cost  \
# Generator                 ...
# Arnot*        428.080386  ...   1.0       False           0.0             0.0
# Arnot**       428.079723  ...   1.0       False           0.0             0.0
# Camden*       536.772465  ...   1.0       False           0.0             0.0
# Camden**      559.254617  ...   1.0       False           0.0             0.0
# Duvha*        315.197862  ...   1.0       False           0.0             0.0
#
#           min_up_time  min_down_time  up_time_before  down_time_before  \
# Generator
# Arnot*              0              0               1                 0
# Arnot**             0              0               1                 0
# Camden*             0              0               1                 0
# Camden**            0              0               1                 0
# Duvha*              0              0               1                 0
#
#            ramp_limit_start_up  ramp_limit_shut_down
# Generator
# Arnot*                     1.0                   1.0
# Arnot**                    1.0                   1.0
# Camden*                    1.0                   1.0
# Camden**                   1.0                   1.0
# Duvha*                     1.0                   1.0
#
# [5 rows x 31 columns]

# %%
# Generator outputs

# %%
generator_outputs = n.generators_t.p
print(generator_outputs)
# Out:
# Generator                   Acacia  Ankerlig      Arnot*     Arnot**  \
# period timestep
# 2030   2030-01-01 00:00:00    51.3     399.6  394.382522  394.382522
#        2030-01-02 01:00:00    51.3     399.6  334.800000  334.800000
#        2030-01-03 02:00:00    51.3     399.6  394.382522  394.382522
#        2030-01-04 03:00:00    51.3     399.6  394.382522  394.382522
#        2030-01-05 04:00:00    51.3     399.6  394.382522  394.382522
# ...                            ...       ...         ...         ...
#        2030-12-27 10:00:00    51.3     399.6  625.515270  625.515270
#        2030-12-28 11:00:00    51.3     399.6  625.515270  625.515270
#        2030-12-29 12:00:00    51.3     399.6  625.515270  625.515270
#        2030-12-30 13:00:00    51.3     399.6  625.515270  625.515270
#        2030-12-31 14:00:00    51.3     399.6  625.515270  625.515270
#
# Generator                         Avon  BLOEMFONTEIN REIPPPP_BW1_solar  \
# period timestep
# 2030   2030-01-01 00:00:00    0.000000                          0.0000
#        2030-01-02 01:00:00    0.000000                          0.0000
#        2030-01-03 02:00:00    0.000000                          0.0000
#        2030-01-04 03:00:00    0.000000                          0.0000
#        2030-01-05 04:00:00    0.000000                          0.0000
# ...                                ...                             ...
#        2030-12-27 10:00:00    0.000000                         36.6776
#        2030-12-28 11:00:00  624.923269                         47.1200
#        2030-12-29 12:00:00  252.866379                         49.7040
#        2030-12-30 13:00:00    0.000000                         45.8280
#        2030-12-31 14:00:00    0.000000                         17.9056
#
# Generator                   BLOEMFONTEIN hydro-import_2020  \
# period timestep
# 2030   2030-01-01 00:00:00                             0.0
#        2030-01-02 01:00:00                             0.0
#        2030-01-03 02:00:00                             0.0
#        2030-01-04 03:00:00                             0.0
#        2030-01-05 04:00:00                             0.0
# ...                                                    ...
#        2030-12-27 10:00:00                             0.0
#        2030-12-28 11:00:00                             0.0
#        2030-12-29 12:00:00                             0.0
#        2030-12-30 13:00:00                             0.0
#        2030-12-31 14:00:00                             0.0
#
# Generator                   BLOEMFONTEIN hydro-import_2022  \
# period timestep
# 2030   2030-01-01 00:00:00                             0.0
#        2030-01-02 01:00:00                             0.0
#        2030-01-03 02:00:00                             0.0
#        2030-01-04 03:00:00                             0.0
#        2030-01-05 04:00:00                             0.0
# ...                                                    ...
#        2030-12-27 10:00:00                             0.0
#        2030-12-28 11:00:00                             0.0
#        2030-12-29 12:00:00                             0.0
#        2030-12-30 13:00:00                             0.0
#        2030-12-31 14:00:00                             0.0
#
# Generator                   BLOEMFONTEIN hydro-import_2024  \
# period timestep
# 2030   2030-01-01 00:00:00                             0.0
#        2030-01-02 01:00:00                             0.0
#        2030-01-03 02:00:00                             0.0
#        2030-01-04 03:00:00                             0.0
#        2030-01-05 04:00:00                             0.0
# ...                                                    ...
#        2030-12-27 10:00:00                             0.0
#        2030-12-28 11:00:00                             0.0
#        2030-12-29 12:00:00                             0.0
#        2030-12-30 13:00:00                             0.0
#        2030-12-31 14:00:00                             0.0
#
# Generator                   BLOEMFONTEIN hydro-import_2026  ...  \
# period timestep                                             ...
# 2030   2030-01-01 00:00:00                             0.0  ...
#        2030-01-02 01:00:00                             0.0  ...
#        2030-01-03 02:00:00                             0.0  ...
#        2030-01-04 03:00:00                             0.0  ...
#        2030-01-05 04:00:00                             0.0  ...
# ...                                                    ...  ...
#        2030-12-27 10:00:00                             0.0  ...
#        2030-12-28 11:00:00                             0.0  ...
#        2030-12-29 12:00:00                             0.0  ...
#        2030-12-30 13:00:00                             0.0  ...
#        2030-12-31 14:00:00                             0.0  ...
#
# Generator                   WESTRAND onwind_2024  WESTRAND onwind_2026  \
# period timestep
# 2030   2030-01-01 00:00:00                   0.0                   0.0
#        2030-01-02 01:00:00                   0.0                   0.0
#        2030-01-03 02:00:00                   0.0                   0.0
#        2030-01-04 03:00:00                   0.0                   0.0
#        2030-01-05 04:00:00                   0.0                   0.0
# ...                                          ...                   ...
#        2030-12-27 10:00:00                   0.0                   0.0
#        2030-12-28 11:00:00                   0.0                   0.0
#        2030-12-29 12:00:00                   0.0                   0.0
#        2030-12-30 13:00:00                   0.0                   0.0
#        2030-12-31 14:00:00                   0.0                   0.0
#
# Generator                   WESTRAND onwind_2028  WESTRAND onwind_2030  \
# period timestep
# 2030   2030-01-01 00:00:00                   0.0                   0.0
#        2030-01-02 01:00:00                   0.0                   0.0
#        2030-01-03 02:00:00                   0.0                   0.0
#        2030-01-04 03:00:00                   0.0                   0.0
#        2030-01-05 04:00:00                   0.0                   0.0
# ...                                          ...                   ...
#        2030-12-27 10:00:00                   0.0                   0.0
#        2030-12-28 11:00:00                   0.0                   0.0
#        2030-12-29 12:00:00                   0.0                   0.0
#        2030-12-30 13:00:00                   0.0                   0.0
#        2030-12-31 14:00:00                   0.0                   0.0
#
# Generator                   WESTRAND solar_2020  WESTRAND solar_2022  \
# period timestep
# 2030   2030-01-01 00:00:00                  0.0                  0.0
#        2030-01-02 01:00:00                  0.0                  0.0
#        2030-01-03 02:00:00                  0.0                  0.0
#        2030-01-04 03:00:00                  0.0                  0.0
#        2030-01-05 04:00:00                  0.0                  0.0
# ...                                         ...                  ...
#        2030-12-27 10:00:00                  0.0                  0.0
#        2030-12-28 11:00:00                  0.0                  0.0
#        2030-12-29 12:00:00                  0.0                  0.0
#        2030-12-30 13:00:00                  0.0                  0.0
#        2030-12-31 14:00:00                  0.0                  0.0
#
# Generator                   WESTRAND solar_2024  WESTRAND solar_2026  \
# period timestep
# 2030   2030-01-01 00:00:00                  0.0                  0.0
#        2030-01-02 01:00:00                  0.0                  0.0
#        2030-01-03 02:00:00                  0.0                  0.0
#        2030-01-04 03:00:00                  0.0                  0.0
#        2030-01-05 04:00:00                  0.0                  0.0
# ...                                         ...                  ...
#        2030-12-27 10:00:00                  0.0                  0.0
#        2030-12-28 11:00:00                  0.0                  0.0
#        2030-12-29 12:00:00                  0.0                  0.0
#        2030-12-30 13:00:00                  0.0                  0.0
#        2030-12-31 14:00:00                  0.0                  0.0
#
# Generator                   WESTRAND solar_2028  WESTRAND solar_2030
# period timestep
# 2030   2030-01-01 00:00:00                  0.0                  0.0
#        2030-01-02 01:00:00                  0.0                  0.0
#        2030-01-03 02:00:00                  0.0                  0.0
#        2030-01-04 03:00:00                  0.0                  0.0
#        2030-01-05 04:00:00                  0.0                  0.0
# ...                                         ...                  ...
#        2030-12-27 10:00:00                  0.0                  0.0
#        2030-12-28 11:00:00                  0.0                  0.0
#        2030-12-29 12:00:00                  0.0                  0.0
#        2030-12-30 13:00:00                  0.0                  0.0
#        2030-12-31 14:00:00                  0.0                  0.0
#
# [351 rows x 681 columns]

# %%
n.generators_t.p_max_pu #.head()

# %%
n.generators_t.p_max_pu.loc["2020":"2030", "BLOEMFONTEIN onwind_2020"].plot(figsize=(15,3))

# %%
n.generators_t.p_max_pu.loc["2020":"2030", "BLOEMFONTEIN solar_2020"].plot(figsize=(15,3))

# %%
### Optimal Generator capacities

# %%
n.generators.groupby("carrier").p_nom_opt.sum() / 1e3 #GW
# Out:
# carrier
# CCGT                 0.160606
# CSP                  0.600000
# OCGT                 0.000000
# biomass              0.193060
# coal                41.942000
# gas                  3.844000
# hydro                0.683020
# hydro-import         1.764000
# load_shedding    27000.000000
# nuclear              1.854000
# onwind               3.442590
# solar                2.287070
# Name: p_nom_opt, dtype: float64

# %%
capacities = n.generators.groupby("carrier").p_nom_opt.sum() / 1e3 #GW

ax = capacities.plot.bar(figsize=(15,6), rot=0)
ax.set_xlabel("Carrier")
ax.set_ylabel("Capacity (GW)")
ax.set_title("Optimal Generator Capacities by Carrier")
plt.show()

# %%
capacities = n.generators.groupby("carrier").p_nom_opt.sum() / 1e3 #GW
capacities = capacities.drop("load_shedding")

ax = capacities.plot.bar(figsize=(15,6), rot=0)
ax.set_xlabel("Carrier")
ax.set_ylabel("Capacity (GW)")
ax.set_title("Optimal Generator Capacities by Carrier")
plt.show()

# %%
#### Renewable / Fossil

# %%
capacities = n.generators.groupby("carrier").p_nom_opt.sum() / 1e3 #GW

renewables = capacities.loc[["CSP", "biomass", "hydro", "hydro-import", "onwind", "solar"]].sum()
nuclear = capacities.loc[["nuclear"]].sum()
fossil_fuels = capacities.sum() - renewables - nuclear

print("Renewable capacities (GW):", renewables)
print("Fossil fuel capacities (GW):", fossil_fuels)
print("Nuclear fuel capacities (GW):", nuclear)
# Out:
# Renewable capacities (GW): 8.96974
# Fossil fuel capacities (GW): 27045.946606188132
# Nuclear fuel capacities (GW): 1.854

# %%
# Generation mix

# %%
gen_type = {'Renewable': ['solar', 'onwind', 'hydro', 'hydro-import', 'CSP', 'biomass'], 
            'Non-renewable': ['coal', 'gas', 'CCGT', 'OCGT', 'nuclear']}
gen_mix = n.generators.groupby(n.generators.carrier.apply(lambda x: 'Renewable' if x in gen_type['Renewable'] else 'Non-renewable'))\
            .p_nom_opt.sum() / 1e3 # convert to GW

gen_mix.plot(kind='bar', stacked=True, rot=0, color=['orange', 'blue'])
plt.xlabel('Generator Type')
plt.ylabel('Capacity (GW)')
plt.title('Generation Mix')
plt.show()

# %% [markdown]
# # 2.3 Carriers

# %%
n.carriers
# Out:
#               co2_emissions    color             nice_name  max_growth  \
# Carrier
# CSP                  0.0000  #FEED82                   Csp         inf
# biomass              0.0000  #0c6013               Biomass         inf
# PHS                  0.0000  #004F95  Pumped Hydro Storage         inf
# coal                 0.3000  #3C3C3C                  Coal         inf
# gas                  0.1794  #d35050                   Gas         inf
# hydro                0.0000  #004F95                 Hydro         inf
# hydro-import         0.0000  #004F95          Hydro-Import         inf
# nuclear              0.0000  #C84936               Nuclear         inf
# CCGT                 0.1794  #CCC8C8                  CCGT         inf
# OCGT                 0.1794  #8D7867                  OCGT         inf
# battery              0.0000  #AA68AA               Battery         inf
# Load                 0.0000                                        inf
#
#               max_relative_growth
# Carrier
# CSP                           0.0
# biomass                       0.0
# PHS                           0.0
# coal                          0.0
# gas                           0.0
# hydro                         0.0
# hydro-import                  0.0
# nuclear                       0.0
# CCGT                          0.0
# OCGT                          0.0
# battery                       0.0
# Load                          0.0

# %%
renewable_capacity = n.generators[n.generators.type.isin(['wind', 'solar'])].p_nom.sum()

print(f"The installed capacity of renewable energy generators is {renewable_capacity:.2f} MW.")

# %% [markdown]
# # 2.4 Storage

# %%
n.storage_units.head()

# %%
# Optimal Storage capacities

# %%
(n.storage_units_t.state_of_charge.sum(axis=1).mean() / 1e6).plot(figsize=(15,3))

# %%
(n.storage_units_t.state_of_charge['2020':'2030'].filter(like='PHS', axis=1).sum(axis=1) /1e6).plot(figsize=(15,3))

# %% [markdown]
# # 2.5 Lines

# %%
n.lines.head()

# %% [markdown]
# ### Transmission Line Expansion

# %%
(n.lines.s_nom_opt - n.lines.s_nom).head(5)

# %%
## Line flows

# %%
line_flows = n.lines_t.p0
print(line_flows)

# %% [markdown]
# # 2.6 Buses

# %%
n.buses

# %% [markdown]
# # 3. Total Annual System Costs in billion

# %%
n.objective/1e9

# %% [markdown]
# # 4. CO2 Emissions

# %%
#### Total CO2 emissions by the network (efficiency and fuel source)

# %%
emissions = n.generators_t.p / n.generators.efficiency * n.generators.carrier.map(n.carriers.co2_emissions)

# %%
emissions.sum().sum()
# Out:
# 8672669.484277314

# %%
#### Plot total CO2 emissions

# %%
emissions = (n.generators_t.p / n.generators.efficiency * n.generators.carrier.map(n.carriers.co2_emissions)).sum(axis=1)

emissions.index = pd.date_range(start='2030-01-01', periods=len(emissions), freq='D')

emissions.plot(figsize=(15, 3), title='Change in CO2 Emissions over Time', xlabel='Time (daily)', ylabel='Total CO2 Emissions')
# Out:
# <Axes: title={'center': 'Change in CO2 Emissions over Time'}, xlabel='Time (weekly)', ylabel='Total CO2 Emissions'>

# %%
fig, ax = plt.subplots()

ax.plot(n.generators_t.p / n.generators.efficiency * n.generators.carrier.map(n.carriers.co2_emissions)).sum(axis=1)

ax.set_xlabel('Time')
ax.set_ylabel('Total CO2 Emissions')
ax.set_title('Change in CO2 Emissions over Time')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [13], line 3
#       1 fig, ax = plt.subplots()
# ----> 3 ax.plot(n.generators_t.p / n.generators.efficiency * n.generators.carrier.map(n.carriers.co2_emissions)).sum(axis=1)
#       5 ax.set_xlabel('Time')
#       6 ax.set_ylabel('Total CO2 Emissions')
#
# File ~/anaconda3/envs/pypsa-za/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File ~/anaconda3/envs/pypsa-za/lib/python3.11/site-packages/matplotlib/axes/_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File ~/anaconda3/envs/pypsa-za/lib/python3.11/site-packages/matplotlib/axes/_base.py:2327, in _AxesBase._update_line_limits(self, line)
#    2323 def _update_line_limits(self, line):
#    2324     """
#    2325     Figures out the data limit of the given line, updating self.dataLim.
#    2326     """
# -> 2327     path = line.get_path()
#    2328     if path.vertices.size == 0:
#    2329         return
#
# File ~/anaconda3/envs/pypsa-za/lib/python3.11/site-packages/matplotlib/lines.py:1029, in Line2D.get_path(self)
#    1027 """Return the `~matplotlib.path.Path` associated with this line."""
#    1028 if self._invalidy or self._invalidx:
# -> 1029     self.recache()
#    1030 return self._path
#
# File ~/anaconda3/envs/pypsa-za/lib/python3.11/site-packages/matplotlib/lines.py:657, in Line2D.recache(self, always)
#     655 if always or self._invalidx:
#     656     xconv = self.convert_xunits(self._xorig)
# --> 657     x = _to_unmasked_float_array(xconv).ravel()
#     658 else:
#     659     x = self._x
#
# File ~/anaconda3/envs/pypsa-za/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335, in _to_unmasked_float_array(x)
#    1333     return np.ma.asarray(x, float).filled(np.nan)
#    1334 else:
# -> 1335     return np.asarray(x, float)
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# # 5. Plot Network Analysis

# %%
import cartopy.crs as ccrs

# %%
loading =(n.lines_t.p0.abs().mean().sort_index() / (n.lines.s_nom_opt*n.lines.s_max_pu).sort_index()).fillna(0.)

# %%
#### PlateCarree, Mercator, Orthographic

# %%
fig,ax =plt.subplots(
            figsize=(10,10),
            subplot_kw={"projection": ccrs.PlateCarree()}
)

n.plot(ax=ax,
      bus_colors='gray',
      branch_components=["Line"],
      line_widths=n.lines.s_nom_opt/3e3,
      line_colors=loading,
      line_cmap=plt.cm.viridis,
      color_geomap=True,
      bus_sizes=0)

ax.axis('off');

# %%
n.plot(bus_sizes=1, margin=1);

# %%
#### pmax per unit by carriers

# %%
n.generators_t.p_max_pu.groupby(n.generators.carrier, axis=1).mean().plot(ylabel='p.u.')

# %%
# Plant Capacities - delete Load Shedding

# %%
n.generators.groupby("carrier").p_nom.sum().div(1e3).plot.barh()
plt.xlabel('GW')
